# %%
import pandas as pd

# %%
# !pip3 install xlrd

# %%
df = pd.read_excel("richpeople.xlsx")
df.head()
# Out:
#    year                         name  rank           citizenship countrycode  \
# 0  2001          A Jerrold Perenchio   151         United States         USA
# 1  2014         A. Jerrold Perenchio   663         United States         USA
# 2  2001  Abdul Al Rahman  Al Jeraisy   336          Saudi Arabia         SAU
# 3  2001        Abdul Aziz Al Ghurair   251  United Arab Emirates         ARE
# 4  1996       Abdul Aziz Al-Sulaiman   404          Saudi Arabia         SAU
#
#    networthusbillion   selfmade         typeofwealth gender   age   ...     \
# 0                3.0  self-made            executive   male  70.0   ...
# 1                2.6  self-made            executive   male  83.0   ...
# 2                1.5  self-made  founder non-finance   male   NaN   ...
# 3                1.9  inherited            inherited   male  47.0   ...
# 4                1.0  self-made    self-made finance   male   0.0   ...
#
# ...

# %% [markdown]
# ## What country are most billionaires from?

# %%
billionaires_2014 = df[df['year'] == 2014]

# %%
billionaires_2014
# Out:
#       year                          name  rank           citizenship  \
# 1     2014          A. Jerrold Perenchio   663         United States
# 5     2014            Abdulla Al Futtaim   687  United Arab Emirates
# 6     2014  Abdulla bin Ahmad Al Ghurair   305  United Arab Emirates
# 8     2014             Abdullah Al Rajhi   731          Saudi Arabia
# 9     2014              Abdulsamad Rabiu  1372               Nigeria
# 12    2014               Abigail Johnson    50         United States
# 15    2014       Abilio dos Santos Diniz   609                Brazil
# 17    2014                 Achmad Hamami  1092             Indonesia
# 18    2014                    Adi Godrej   446                 India
# 23    2014      Aerin Lauder Zinterhofer  1465         United States
# 25    2014                   Ahmet Calik  1465                Turkey
# 26    2014             Ahmet Nazif Zorlu  1372                Turkey
# 27    2014                  Ahsen Ozokur  1143                Turkey
# ...

# %%
top_countries_per_billionaires = billionaires_2014['countrycode'].value_counts().head(10)
top_countries_per_billionaires
# Out:
# USA    499
# CHN    152
# RUS    111
# DEU     85
# BRA     65
# IND     56
# GBR     47
# HKG     45
# FRA     43
# ITA     35
# Name: countrycode, dtype: int64

# %%
avg_networth_per_billionaire_per_country = top_aggr_networth / top_countries_per_billionaires
avg_networth_per_billionaire_per_country.sort_values(ascending=False)
# Out:
# FRA    5.472093
# HKG    4.748889
# DEU    4.722353
# USA    4.654108
# ITA    4.517143
# RUS    3.806306
# IND    3.426786
# GBR    3.234043
# BRA    2.956923
# CHN    2.472368
# dtype: float64

# %% [markdown]
# ## Which country has the higher aggregated net worth?

# %%
top_aggr_networth = billionaires_2014.groupby('countrycode')['networthusbillion'].sum().sort_values(ascending=False).head(10)
top_aggr_networth
# Out:
# countrycode
# USA    2322.4
# RUS     422.5
# DEU     401.4
# CHN     375.8
# FRA     235.3
# HKG     213.7
# BRA     192.2
# IND     191.9
# ITA     158.1
# GBR     152.0
# Name: networthusbillion, dtype: float64

# %% [markdown]
# ## Who are the top 10 richest billionaires?

# %%
billionaires_2014.sort_values(by='networthusbillion', ascending=False).head(10)
# Out:
#       year              name  rank    citizenship countrycode  \
# 284   2014        Bill Gates     1  United States         USA
# 348   2014  Carlos Slim Helu     2         Mexico         MEX
# 124   2014    Amancio Ortega     3          Spain         ESP
# 2491  2014    Warren Buffett     4  United States         USA
# 1377  2014     Larry Ellison     5  United States         USA
# 509   2014        David Koch     6  United States         USA
# 381   2014      Charles Koch     6  United States         USA
# 2185  2014   Sheldon Adelson     8  United States         USA
# 429   2014    Christy Walton     9  United States         USA
# 1128  2014        Jim Walton    10  United States         USA
#
#       networthusbillion   selfmade              typeofwealth  gender   age  \
# 284                76.0  self-made       founder non-finance    male  58.0
# 348                72.0  self-made  privatized and resources    male  74.0
# ...

# %% [markdown]
# ## What's the average wealth of a billionaire? Male? Female?

# %%
billionaires_2014.describe()
# Out:
# /Users/olayaargueso/.virtualenvs/data-analysis/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#          year         rank  networthusbillion          age        north  \
# count  1653.0  1653.000000        1653.000000  1590.000000  1653.000000
# mean   2014.0   809.442226           3.904658    63.342138     0.573503
# std       0.0   463.910597           5.748520    13.137743     0.494718
# min    2014.0     1.000000           1.000000    24.000000     0.000000
# 25%    2014.0   408.000000           1.400000          NaN     0.000000
# 50%    2014.0   828.000000           2.100000          NaN     1.000000
# 75%    2014.0  1210.000000           3.700000          NaN     1.000000
# max    2014.0  1565.000000          76.000000    98.000000     1.000000
#
#        politicalconnection      founder  foundingdate  gdpcurrentus
# count                 56.0  1653.000000   1641.000000           0.0
# ...

# %%
male_billionaires = billionaires_2014[billionaires_2014['gender'] == 'male']
male_billionaires.describe()
# Out:
# /Users/olayaargueso/.virtualenvs/data-analysis/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#          year         rank  networthusbillion          age        north  \
# count  1473.0  1473.000000        1473.000000  1424.000000  1473.000000
# mean   2014.0   810.380855           3.902716    63.427669     0.556687
# std       0.0   463.014514           5.801227    13.025046     0.496945
# min    2014.0     1.000000           1.000000    29.000000     0.000000
# 25%    2014.0   408.000000           1.400000          NaN     0.000000
# 50%    2014.0   828.000000           2.100000          NaN     1.000000
# 75%    2014.0  1210.000000           3.700000          NaN     1.000000
# max    2014.0  1565.000000          76.000000    98.000000     1.000000
#
#        politicalconnection      founder  foundingdate  gdpcurrentus
# count                 50.0  1473.000000   1461.000000           0.0
# ...

# %%
female_billionaires = billionaires_2014[billionaires_2014['gender'] == 'female']
female_billionaires.describe()
# Out:
# /Users/olayaargueso/.virtualenvs/data-analysis/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#          year         rank  networthusbillion         age       north  \
# count   180.0   180.000000         180.000000  166.000000  180.000000
# mean   2014.0   801.761111           3.920556   62.608434    0.711111
# std       0.0   472.418458           5.312604   14.087938    0.454510
# min    2014.0     9.000000           1.000000   24.000000    0.000000
# 25%    2014.0   408.000000           1.400000         NaN    0.000000
# 50%    2014.0   764.000000           2.300000         NaN    1.000000
# 75%    2014.0  1210.000000           3.700000         NaN    1.000000
# max    2014.0  1565.000000          36.700000   95.000000    1.000000
#
#        politicalconnection     founder  foundingdate  gdpcurrentus
# count                  6.0  180.000000    180.000000           0.0
# ...

# %% [markdown]
# ## Who is the poorest billionaire? Who are the top 10 poorest billionaires?

# %%
billionaires_2014.sort_values(by='networthusbillion').head(10)
# Out:
#       year               name  rank    citizenship countrycode  \
# 234   2014        B.R. Shetty  1565          India         IND
# 2092  2014       Rostam Azizi  1565       Tanzania         TZA
# 2401  2014         Tory Burch  1565  United States         USA
# 734   2014         Fred Chang  1565  United States         USA
# 171   2014     Angela Bennett  1565      Australia         AUS
# 748   2014            Fu Kwan  1565          China         CHN
# 2107  2014     Ryan Kavanaugh  1565  United States         USA
# 1783  2014  O. Francis Biondi  1565  United States         USA
# 1371  2014       Lam Fong Ngo  1565          Macau         MAC
# 702   2014      Feng Hailiang  1565          China         CHN
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 234                 1.0  self-made  founder non-finance    male  72.0
# 2092                1.0  self-made            executive    male  49.0
# ...

# %% [markdown]
# ## 'What is relationship to company'? And what are the most common relationships? Male vs. female?

# %%
billionaires_2014['relationshiptocompany'].value_counts().head(20)
# Out:
# founder                                 818
# relation                                515
# owner                                    79
# chairman                                 64
# investor                                 30
# Chairman and Chief Executive Officer     15
# CEO                                       8
# president                                 8
# Chairman                                  8
# ceo                                       8
# founder and chairman                      6
# former CEO                                5
# partner                                   4
# founder and CEO                           4
# Vice Chairman                             3
# relation and chairman                     3
# founder/chairman                          3
# Relation                                  3
# executive chairman                        3
# founder/vice chairman                     2
# Name: relationshiptocompany, dtype: int64

# %%
female_billionaires['relationshiptocompany'].value_counts().head(20)
# Out:
# relation                    139
# founder                      27
# owner                         4
# founder and chairwoman        1
# president and ceo             1
# COO                           1
# Vice Chairman                 1
# chairwomen                    1
# founder, chairwoman, ceo      1
# investor                      1
# inherited                     1
# relative                      1
# relation and ceo              1
# Name: relationshiptocompany, dtype: int64

# %%
male_billionaires['relationshiptocompany'].value_counts().head(20)
# Out:
# founder                                 791
# relation                                376
# owner                                    75
# chairman                                 64
# investor                                 29
# Chairman and Chief Executive Officer     15
# Chairman                                  8
# president                                 8
# CEO                                       8
# ceo                                       8
# founder and chairman                      6
# former CEO                                5
# partner                                   4
# founder and CEO                           4
# relation and chairman                     3
# founder/chairman                          3
# executive chairman                        3
# Relation                                  3
# founder/vice chairman                     2
# Vice Chairman                             2
# Name: relationshiptocompany, dtype: int64

# %% [markdown]
# ## Most common source of wealth? Male vs. female?

# %%
billionaires_2014['sourceofwealth'].value_counts().head(20)
# Out:
# real estate            107
# diversified             69
# retail                  63
# investments             60
# pharmaceuticals         42
# hedge funds             34
# banking                 33
# construction            32
# media                   24
# consumer goods          19
# software                18
# private equity          16
# finance                 15
# steel                   13
# chemicals               12
# mining                  12
# manufacturing           12
# casinos                 11
# hotels, investments     11
# telecom                 10
# Name: sourceofwealth, dtype: int64

# %%
female_billionaires['sourceofwealth'].value_counts().head(20)
# Out:
# diversified            9
# real estate            7
# media                  6
# hotels, investments    5
# construction           5
# consumer goods         5
# chemicals              4
# Wal-Mart               4
# casinos                4
# cleaning products      4
# banking                3
# Samsung                3
# retail                 3
# mining                 3
# commodities            3
# packaging              3
# pipelines              3
# hotels, restaurants    2
# bank, media            2
# coffee                 2
# Name: sourceofwealth, dtype: int64

# %%
male_billionaires['sourceofwealth'].value_counts().head(20)
# Out:
# real estate        100
# retail              60
# diversified         60
# investments         58
# pharmaceuticals     40
# hedge funds         34
# banking             30
# construction        27
# software            18
# media               18
# private equity      16
# finance             15
# consumer goods      14
# manufacturing       12
# steel               11
# telecom             10
# mining               9
# electronics          9
# chemicals            8
# education            8
# Name: sourceofwealth, dtype: int64

# %% [markdown]
# ## What are the most common industries for billionaires to come from? What's the total amount of billionaire money from each industry?

# %%
df.columns
# Out:
# Index(['year', 'name', 'rank', 'citizenship', 'countrycode',
#        'networthusbillion', 'selfmade', 'typeofwealth', 'gender', 'age',
#        'industry', 'IndustryAggregates', 'region', 'north',
#        'politicalconnection', 'founder', 'generationofinheritance', 'sector',
#        'company', 'companytype', 'relationshiptocompany', 'foundingdate',
#        'gdpcurrentus', 'sourceofwealth', 'notes', 'notes2', 'source',
#        'source_2', 'source_3', 'source_4'],
#       dtype='object')

# %%
billionaires_2014['industry'].value_counts()
# Out:
# Consumer                           291
# Real Estate                        190
# Retail, Restaurant                 174
# Diversified financial              132
# Technology-Computer                131
# Money Management                   122
# Media                              104
# Energy                              87
# Non-consumer industrial             83
# Technology-Medical                  78
# Mining and metals                   68
# Constrution                         61
# Other                               59
# Hedge funds                         43
# Private equity/leveraged buyout     18
# 0                                    6
# Venture Capital                      5
# Name: industry, dtype: int64

# %%
billionaires_2014.groupby('industry')['networthusbillion'].sum().sort_values(ascending=False).head(10)
# Out:
# industry
# Consumer                   1177.8
# Retail, Restaurant          820.9
# Technology-Computer         684.6
# Diversified financial       614.4
# Real Estate                 573.8
# Media                       490.5
# Money Management            381.3
# Energy                      340.5
# Non-consumer industrial     298.4
# Mining and metals           240.6
# Name: networthusbillion, dtype: float64

# %% [markdown]
# ## How many self made billionaires vs. others?

# %%
billionaires_2014['selfmade'].value_counts()
# Out:
# self-made    1146
# inherited     505
# Name: selfmade, dtype: int64

# %% [markdown]
# ## How old are billionaires? How old are billionaires self made vs. non self made? or different industries?

# %% [markdown]
# The most typical age for a billionaire is 64, followed by 60.

# %%
billionaires_2014['age'].value_counts().head(20)
# Out:
# 64.0    53
# 60.0    51
# 62.0    51
# 69.0    48
# 49.0    47
# 50.0    46
# 68.0    45
# 52.0    43
# 58.0    43
# 63.0    42
# 57.0    42
# 59.0    42
# 61.0    41
# 70.0    40
# 66.0    40
# 72.0    39
# 56.0    38
# 71.0    37
# 73.0    36
# 55.0    34
# Name: age, dtype: int64

# %% [markdown]
# The mean of their age is also over 60:

# %%
billionaires_2014['age'].describe()
# Out:
# /Users/olayaargueso/.virtualenvs/data-analysis/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    1590.000000
# mean       63.342138
# std        13.137743
# min        24.000000
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max        98.000000
# Name: age, dtype: float64

# %% [markdown]
# The mean age for self-made billionaires is slightly lower.

# %%
billionaires_2014.groupby('selfmade')['age'].describe()
# Out:
# /Users/olayaargueso/.virtualenvs/data-analysis/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# selfmade
# inherited  count     476.000000
#            mean       64.962185
#            std        13.174403
#            min        24.000000
#            25%              NaN
#            50%              NaN
#            75%              NaN
#            max        98.000000
# self-made  count    1112.000000
#            mean       62.625899
#            std        13.054631
#            min        29.000000
#            25%              NaN
#            50%              NaN
#            75%              NaN
#            max        96.000000
# Name: age, dtype: float64

# %%
billionaires_2014.groupby('industry')['age'].describe()
# Out:
# /Users/olayaargueso/.virtualenvs/data-analysis/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# industry
# 0                      count      5.000000
#                        mean      63.600000
#                        std       14.170392
#                        min       49.000000
#                        25%             NaN
#                        50%             NaN
#                        75%             NaN
#                        max       85.000000
# Constrution            count     58.000000
#                        mean      64.965517
#                        std       14.234829
#                        min       33.000000
#                        25%             NaN
#                        50%             NaN
#                        75%             NaN
#                        max       92.000000
# Consumer               count    276.000000
# ...

# %% [markdown]
# ## What is the most common founding date?

# %%
billionaires_2014['foundingdate'].value_counts().head(10)
# Out:
# 1995.0    49
# 1992.0    42
# 1993.0    42
# 1994.0    42
# 1991.0    36
# 1999.0    33
# 1969.0    32
# 1990.0    32
# 1988.0    32
# 1998.0    31
# Name: foundingdate, dtype: int64

# %%
billionaires_2014.groupby('foundingdate')['age'].value_counts().sort_values(ascending=False).head(20)
# Out:
# foundingdate  age
# 1995.0        49.0    8
# 1994.0        46.0    8
# 1993.0        48.0    7
# 1995.0        50.0    5
# 1994.0        58.0    5
# 1990.0        62.0    5
# 1995.0        51.0    5
# 1999.0        49.0    5
# 1987.0        64.0    4
# 1992.0        49.0    4
# 1971.0        69.0    4
# 1992.0        56.0    4
# 1975.0        72.0    4
# 1991.0        54.0    4
# 1977.0        69.0    4
# 1999.0        50.0    4
# 1992.0        54.0    4
# 1980.0        56.0    4
# 1996.0        42.0    4
# 1993.0        50.0    4
# Name: age, dtype: int64

# %% [markdown]
# ## What about their political connections?

# %%
billionaires_2014.columns
# Out:
# Index(['year', 'name', 'rank', 'citizenship', 'countrycode',
#        'networthusbillion', 'selfmade', 'typeofwealth', 'gender', 'age',
#        'industry', 'IndustryAggregates', 'region', 'north',
#        'politicalconnection', 'founder', 'generationofinheritance', 'sector',
#        'company', 'companytype', 'relationshiptocompany', 'foundingdate',
#        'gdpcurrentus', 'sourceofwealth', 'notes', 'notes2', 'source',
#        'source_2', 'source_3', 'source_4'],
#       dtype='object')

# %%
billionaires_2014['politicalconnection'].head()
# Out:
# 1   NaN
# 5   NaN
# 6   NaN
# 8   NaN
# 9   NaN
# Name: politicalconnection, dtype: float64

# %%
billionaires_2014['politicalconnection'] != None
# Out:
# 1       True
# 5       True
# 6       True
# 8       True
# 9       True
# 12      True
# 15      True
# 17      True
# 18      True
# 23      True
# 25      True
# 26      True
# 27      True
# 28      True
# 29      True
# 30      True
# 34      True
# 37      True
# 38      True
# 39      True
# 40      True
# 43      True
# 45      True
# 46      True
# 47      True
# 48      True
# 50      True
# 51      True
# 54      True
# 55      True
#         ...
# 2584    True
# 2585    True
# 2586    True
# 2587    True
# 2588    True
# 2589    True
# 2590    True
# 2591    True
# 2592    True
# 2593    True
# 2594    True
# 2595    True
# 2596    True
# 2597    True
# 2598    True
# 2599    True
# 2600    True
# 2601    True
# 2602    True
# 2603    True
# 2604    True
# 2605    True
# 2606    True
# 2607    True
# 2608    True
# 2609    True
# 2610    True
# 2611    True
# 2612    True
# 2613    True
# Name: politicalconnection, dtype: bool

# %% [markdown]
# ## Who are the youngest billionaires? The oldest? Age distribution - maybe make a graph about it?

# %%
billionaires_2014.sort_values(by='age').head(10)
# Out:
#       year                        name  rank    citizenship countrycode  \
# 1838  2014                 Perenna Kei  1284      Hong Kong         HKG
# 605   2014            Dustin Moskovitz   202  United States         USA
# 1586  2014             Mark Zuckerberg    21  United States         USA
# 189   2014         Anton Kathrein, Jr.  1270        Germany         DEU
# 602   2014                Drew Houston  1372  United States         USA
# 54    2014  Albert von Thurn und Taxis  1092        Germany         DEU
# 618   2014             Eduardo Saverin   367         Brazil         BRA
# 2151  2014                Scott Duncan   215  United States         USA
# 2559  2014                 Yang Huiyan   196          China         CHN
# 1569  2014     Marie Besnier Beauvalot   642         France         FRA
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 1838                1.3  inherited            inherited  female  24.0
# ...

# %%
billionaires_2014.sort_values(by='age', ascending=False).head(10)
# Out:
#       year                      name  rank    citizenship countrycode  \
# 516   2014    David Rockefeller, Sr.   580  United States         USA
# 1277  2014             Karl Wlaschek   305        Austria         AUT
# 1328  2014            Kirk Kerkorian   328  United States         USA
# 921   2014             Henry Hillman   687  United States         USA
# 666   2014        Erika Pohl-Stroher  1154        Germany         DEU
# 2292  2014         Sulaiman Al Rajhi   931   Saudi Arabia         SAU
# 181   2014         Anne Cox Chambers    58  United States         USA
# 1275  2014             Karl Albrecht    23        Germany         DEU
# 119   2014  Aloysio de Andrade Faria   483         Brazil         BRA
# 2487  2014            Wang Yung-Tsai   520         Taiwan      Taiwan
#
#       networthusbillion   selfmade         typeofwealth  gender   age  \
# 516                 2.9  inherited            inherited    male  98.0
# ...

# %%
# %matplotlib inline

# %%
billionaires_2014['age'].hist(bins=30)

# %% [markdown]
# ## Maybe just made a graph about how wealthy they are in general?

# %% [markdown]
# The graph belows shows how the majority of billionaires have a fortune that is less than 10 billion US$.

# %%
billionaires_2014['networthusbillion'].hist()

# %% [markdown]
# ## Maybe plot their net worth vs age (scatterplot, zoomed in)

# %%
billionaires_2014.plot(kind='scatter', x='age', y='networthusbillion', xlim=(30, 80) , ylim=(0, 15))

# %% [markdown]
# ## Make a bar graph of the top 10 or 20 richest

# %%
billionaires_2014.sort_values(by='networthusbillion', ascending=False).head(10).plot(kind='bar', x='name', y='networthusbillion', legend=False)

# %%
billionaires_2014.sort_values(by='networthusbillion', ascending=False).head(20).plot(kind='bar', x='name', y='networthusbillion', legend=False)
